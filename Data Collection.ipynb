# %%
import requests
import json

# Replace 'YOUR_API_KEY' with your actual Yelp API key
API_KEY = 'oPu9csxtdGRgjpwJTXDcig-od7UO8s1cN95oW3w2ew3UYa0RsP4KI-2ziuy6rQjY-4XWDYI87Qg0ueb7EH0Jh_oQTy-pG1xKVhVa0TQldZEBtSNH7GIvAbgdHGP3ZHYx'

# Yelp API endpoint
API_ENDPOINT = 'https://api.yelp.com/v3/businesses/search'
API_ENDPOINT_REVIEWS_PRE = 'https://api.yelp.com/v3/businesses/'
API_ENDPOINT_REVIEWS_POST = '/reviews'

current_restaurant_count = 0
restaurant_set = set()

restaraunts = []

for i in range(5):
    # Define your query parameters
    params = {
        'term': 'restaurant',  # Search term
        'location': 'Columbus',  # Location to search in
        'limit': 50,
        'offset': current_restaurant_count
    }

    # Define the headers with your API key
    headers = {
        'Authorization': f'Bearer {API_KEY}'
    }

    try:
        # Make the API request
        response = requests.get(API_ENDPOINT, params=params, headers=headers)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            data = response.json()
            businesses = data.get('businesses', [])

            if businesses:
                current_restaurant_count += len(businesses)
                for business in businesses:
                    business_dict = {}
                    if business['name'] not in restaurant_set:
                        business_dict['name'] = business['name']
                        business_dict['rating'] = business['rating']
                        # Can add more attributes here
                        business_dict['reviews'] = []
                        restaurant_set.add(business['name'])
                            # Define your query parameters
                        params = {
                            'limit': 20,
                        }
                        # Make the API request
                        response = requests.get(f'{API_ENDPOINT_REVIEWS_PRE}{business["id"]}{API_ENDPOINT_REVIEWS_POST}', params=params, headers=headers)
                        # Check if the request was successful (status code 200)
                        if response.status_code == 200:
                            data = response.json()
                            reviews = data.get('reviews', [])
                            if reviews:
                                for review in reviews:
                                    review_dict = {}
                                    review_dict['rating'] = review['rating']
                                    review_dict['text'] = review['text']
                                    review_dict['time_created'] = review['time_created']
                                    business_dict['reviews'].append(review_dict)
                                 
                        restaraunts.append(business_dict)
            else:
                print("No businesses found.")
        else:
            print(f"Error: {response.status_code} - {response.text}")

    except Exception as e:
        print(f"An error occurred: {str(e)}")
# Out:
# Error: 429 - {"error": {"code": "ACCESS_LIMIT_REACHED", "description": "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}

# %%
len(restaraunts)
# Out:
# 195

# %%
restaraunts
# Out:
# [{'name': 'Alqueria Farmhouse Kitchen',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': "First, let me start with the bottom line: Alqueria is in my experience the best farm-to-table restaurant for your money in North America. And I've lived in...",
#     'time_created': '2023-07-20 05:05:07'},
#    {'rating': 4,
#     'text': 'Service was great from start to finish.  Very friendly and very attentive. We came on Saturday as soon as they opened for service. \n\nWe ordered their...',
#     'time_created': '2023-09-02 16:08:55'},
#    {'rating': 4,
#     'text': 'Food was super impressive. Third and Hollywood level vibe but less expensive. The sweet potato appetizer had a sauce that was unbelievable, and the Brussels...',
#     'time_created': '2023-03-21 19:29:29'}]},
#  {'name': 'Harvest Bar + Kitchen',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': "Absolutely delicious and amazing. Harvest has the best pizza I've had yet, and it's very consistent and I have not yet had a bad experience in the many...",
#     'time_created': '2023-05-12 13:00:50'},
#    {'rating': 5,
#     'text': "I stopped into Harvest for some late night dinner, and it was great! There's parking to the side, or you can street park.\n\nThey're known for their pizza,...",
#     'time_created': '2023-04-05 20:20:48'},
#    {'rating': 5,
#     'text': 'Went tonight for dinner and it was great! We got the almond pesto pizza, the vegan pizza, and the Margherita pizza. It was all delicious and sooo good!! We...',
#     'time_created': '2023-08-26 20:12:39'}]},
#  {'name': "Pat and Gracie's",
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'We had very quick and courteous service. The food came out hot and tasted good. \n\nThe only complaint I could have had was the cheese sticks and walleye had...',
#     'time_created': '2023-08-14 05:58:46'},
#    {'rating': 5,
#     'text': 'I love this place! The food is outstanding. I always get the fish and chips, my girlfriend always gets the burger. The pretzel bites are awesome and the...',
#     'time_created': '2023-07-23 15:22:38'},
#    {'rating': 3,
#     'text': "We may have just had bad timing. We dropped by and the place was packed and noisy...two strikes for me. The men selection didn't appeal to me but then I do...",
#     'time_created': '2023-05-04 08:44:51'}]},
#  {'name': 'Understory',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'This is such a unique and lovely gem that almost feels like a secret garden of an eating/drinking experience. Based in the lower portion of an old school...',
#     'time_created': '2023-06-25 11:35:38'},
#    {'rating': 3,
#     'text': "I would like to sincerely thank whomever had the vision to renovate this school as opposed to flattening it to build some cookie cutter building. It's old...",
#     'time_created': '2023-08-13 20:19:17'},
#    {'rating': 2,
#     'text': "Don't bother with the food. Or at least the apps. We were so disappointed in those we didn't bother ordering our meals there. \nWe went because we heard the...",
#     'time_created': '2023-07-15 09:59:26'}]},
#  {'name': 'Tupelo Honey Southern Kitchen & Bar',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'Food was amazing ! \nAnd I enjoyed the drinks idk why my review has to be so long I jus wanna say the food is great',
#     'time_created': '2023-08-18 10:45:01'},
#    {'rating': 3,
#     'text': 'This was my second visit to TH. The service was very slow, dark meat chicken took nearly an hour to prepare, and it seemed everyone around was a little...',
#     'time_created': '2023-07-28 15:41:57'},
#    {'rating': 5,
#     'text': 'Well, the food here that my wife and I had was delicious. She got the fried chicken and fries and said the chicken made her feel like she was back in...',
#     'time_created': '2023-07-15 08:54:49'}]},
#  {'name': 'Derive Brewing',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': "We discovered this brewery last year while participating in Columbus's ale trail and I have to say... it is quickly becoming one of my favorite places in...",
#     'time_created': '2023-08-16 18:36:58'},
#    {'rating': 5,
#     'text': 'Went on a Wednesday night (Smash Burger Deal!) with friends. The food and drinks were amazing and the environment was casual and laid back. \n\nParking: they...',
#     'time_created': '2023-05-17 17:03:59'},
#    {'rating': 5,
#     'text': "Derive Brewing is a great spot to enjoy some delicious food and drinks in Columbus, Ohio. Whether you're in the mood for pizza, fries, or burgers, you'll...",
#     'time_created': '2023-04-30 02:06:11'}]},
#  {'name': 'High Bank Distillery',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'Megan was an awesome tour guide and the spirits were even better than expected!  She was super knowledgeable and had a great personality!',
#     'time_created': '2023-08-04 17:55:45'},
#    {'rating': 5,
#     'text': 'Coworker and I went here to celebrate a hard days work - Incredible food - wonderful atmosphere and staff is incredibly efficient and quick. The food is...',
#     'time_created': '2023-08-07 11:01:28'},
#    {'rating': 4,
#     'text': "Butcher on the bank - smoked old fashion was delicious \n\nKorean Philly was very tasty but couldn't taste any of the Asian features, in a blind taste test I...",
#     'time_created': '2023-08-11 19:29:55'}]},
#  {'name': 'Hawaiian Barbecue',
#   'rating': 4.5,
#   'reviews': [{'rating': 4,
#     'text': 'Auwe, just drove from New Albany and they are closed. (Sign on door says closed on Tuesday) even though online it says open. Next time I guess. \u200d I will try...',
#     'time_created': '2023-07-18 15:03:22'},
#    {'rating': 5,
#     'text': "Great food and large menu that's reasonably priced! Everything we tried was very good. Will definitely be coming back!",
#     'time_created': '2023-07-30 10:20:18'},
#    {'rating': 5,
#     'text': 'Great service and great variety on the menu and good variety of Hawaiian Sun drinks. Definitely going back',
#     'time_created': '2023-07-18 09:23:43'}]},
#  {'name': 'Hiraeth Columbus',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': "For a place that's only been open a few weeks, Hiraeth is running like a restaurant that's been there for years. \n\nThe staff are all wonderfully engaging...",
#     'time_created': '2023-08-17 23:19:01'},
#    {'rating': 4,
#     'text': 'I was dying to come here because i LOVE Chapman\'s. \n\nStarting of with the drinks- The Password is "Caprese" caught my eye because I like savory drinks- the...',
#     'time_created': '2023-09-02 10:14:35'},
#    {'rating': 4,
#     'text': "I was highly anticipating the opening as I am a huge fan of Chapman's Eat. Lucky to have a reservation early on in their opening. I am guessing they will be...",
#     'time_created': '2023-08-18 18:46:44'}]},
#  {'name': 'Galla Park Social',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'A HUGE thank you to the service tonight at Galla Park Social. I went to Galla Park Social on Thursday this past week and unfortunately left my credit card...',
#     'time_created': '2023-07-15 23:19:50'},
#    {'rating': 5,
#     'text': 'What happens at @gallaparksocial stays at Galla, EXCEPT for spreading the word about this NEW menu because it is fire  The new ambiance here is amazing. We...',
#     'time_created': '2023-06-26 13:10:21'},
#    {'rating': 5,
#     'text': 'We moved to the area at the beginning of the year and love all of the variety in food choices! I was excited to see this new spot open up and thought Friday...',
#     'time_created': '2023-05-13 05:02:41'}]},
#  {'name': 'Budd Dairy Food Hall',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'We had a lovely start to our date night here. My wife had her heart set on the fried chicken at the southern food place but they ran out so she got the...',
#     'time_created': '2023-08-07 14:31:14'},
#    {'rating': 5,
#     'text': 'Fun Saturday date night!  We read about in an article that listed it as top ten food halls in the country, so of course had to check it out. \nAs soon as we...',
#     'time_created': '2023-04-11 17:32:34'},
#    {'rating': 5,
#     'text': 'One of my Favorite concepts of food halls to date.\n\nOld building repurposed to a food hall with a large bar and TVs for sports.\n\nThis is a self service...',
#     'time_created': '2023-03-21 10:46:40'}]},
#  {'name': 'Plas Food and Drink',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'I was here for a private event on Sunday.  They are normally closed on Sundays but they hosted a beautiful gathering with the chef and bartender serving...',
#     'time_created': '2023-08-30 11:18:55'},
#    {'rating': 3,
#     'text': 'Plas is fine dinning restaurant that changed its menu for every season. We tried their summer menu \nThey started us off with some fresh bread which was...',
#     'time_created': '2023-08-05 21:22:30'},
#    {'rating': 4,
#     'text': "First time here and had a very enjoyable eve . It's small and a unusual  menue . Our waiter , Xander, did a great job in his suggestion of the wine , which...",
#     'time_created': '2023-07-18 13:27:57'}]},
#  {'name': 'Domo Sushi Kitchen & Bar',
#   'rating': 5.0,
#   'reviews': [{'rating': 5,
#     'text': "We had such a great experience at DOMO! It's the perfect spot for a date night or just somewhere to pop in with friends. The restaurant was casual but had a...",
#     'time_created': '2023-07-27 11:33:31'},
#    {'rating': 5,
#     'text': "New sushi place in the short north! It's a small space but very well decorated and cute. Very clean space, great and fast service. Sushi was so tasty. The...",
#     'time_created': '2023-08-12 17:46:33'},
#    {'rating': 5,
#     'text': 'My friends and I checked out Domo, and we absolutely will be back! Their cuts of fish are so fresh, and we were not disappointed with any of the dishes we...',
#     'time_created': '2023-07-30 11:42:32'}]},
#  {'name': 'Arch City Tavern',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'this my second time here in less then a week!!! lamb sliders are so good with the truffle fries! I had 3 Moscow mules! and te staff is amazing!! I had Abigail N',
#     'time_created': '2023-07-27 14:02:29'},
#    {'rating': 5,
#     'text': 'We moved to Columbus a few months ago and have been looking around nearby for some good places to eat. Tonight my partner chose Arch City Tavern. It was...',
#     'time_created': '2023-05-01 19:51:49'},
#    {'rating': 4,
#     'text': 'Finally checked this place out! We stopped by for their 10th anniversary party and the food and vibes were great! \n\nBurgers are AWESOME. I ordered the Arch...',
#     'time_created': '2023-03-13 07:24:59'}]},
#  {'name': 'Tiger + Lily',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'One of my favorite spots to grab food here in the #cbus is at @tigerandlilyinspired. The appetizers and entrees are pretty amazing here. I have not found a...',
#     'time_created': '2023-09-02 09:12:40'},
#    {'rating': 5,
#     'text': 'Had an awesome lunch and the staff was so attentive! \n\nI had the lemongrass chicken bowl, it was delicious, the chicken had wonderful flavor and was cooked...',
#     'time_created': '2023-07-24 04:53:52'},
#    {'rating': 5,
#     'text': 'I became a fan of Tiger + Lily during the early days of COVID. Over the years I continued to follow their story, especially during the 2020 riots, which...',
#     'time_created': '2023-06-05 05:47:47'}]},
#  {'name': 'Brassica',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'Breezy super mouth feel unending colorful additions.  Side of falafel may take a minute.',
#     'time_created': '2023-08-11 17:09:39'},
#    {'rating': 5,
#     'text': "I've been coming to Brassica quite a bit over the last few years. They've got a Chipotle-style process, where you place an order, then go through an...",
#     'time_created': '2023-06-24 12:29:57'},
#    {'rating': 5,
#     'text': "The Brassica on N High is one of my favorite quick workday lunch spots! It's in such a convenient location, and has ample intimate seating inside which...",
#     'time_created': '2023-06-02 10:46:38'}]},
#  {'name': 'Third and Hollywood',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'As usual, 5 stars, for food, ambience and service. Always a favorite! Their Havana side car is to live for ;-)',
#     'time_created': '2023-07-28 13:20:04'},
#    {'rating': 5,
#     'text': 'SUPER yummy!!! \n\nREALLY liked this place. Visited for a work business happy hour/dinner. We sat in the back with the big tables and somewhat isolated and...',
#     'time_created': '2023-09-04 15:42:18'},
#    {'rating': 3,
#     'text': 'We came here for our monthly supper club. They were very accommodating for our group of 16 and placed us in the private room in the back next to the lovely...',
#     'time_created': '2023-06-22 06:06:54'}]},
#  {'name': 'The Pearl',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'Great Service. Wonderful FOOD! Very nice ambiance.   It was a nice walk from our hotel for a late lunch / early dinner.  They offer their "starters" and...',
#     'time_created': '2023-08-02 16:55:15'},
#    {'rating': 4,
#     'text': 'This is a very nice comfort food type of restaurant. The overall vibe is loud and difficult to vary on a conversation. The waitress was helpful in making...',
#     'time_created': '2023-08-16 04:29:50'},
#    {'rating': 3,
#     'text': 'Back in 2019 this place was one of my favorites in Columbus but sadly over time I feel the quality has gone down. Ordered the New Orleans Oysters, Parmesan...',
#     'time_created': '2023-07-23 18:14:17'}]},
#  {'name': 'Lincoln Social Rooftop',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'Food- a bit smaller than I imagined, but perfect size for tapas. \nService - great here, food comes out efficiently as well as drinks \nDrinks- great, as well...',
#     'time_created': '2023-08-08 17:04:19'},
#    {'rating': 5,
#     'text': 'For my first visit, they really knocked it out of the park. \n\nMy friend moved out of town a while ago and was back to visit. We stopped at another place...',
#     'time_created': '2023-09-02 20:00:14'},
#    {'rating': 4,
#     'text': 'On our first night in Columbus, we had a late dinner at Lincoln Social Rooftop. Upon entry, the front staff checked our IDs, including those of my parents....',
#     'time_created': '2023-08-06 10:53:35'}]},
#  {'name': 'Forbidden Root',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'Its a big open space, lit warmly with a lot of wood.   Has inside and outside dining. The hostess that greeted us was quite friendly.  We chose to sit at...',
#     'time_created': '2023-07-03 11:33:54'},
#    {'rating': 5,
#     'text': 'FR Burger* Single Smash Patty, Giardiniera mayo, Aged Cheddar Cheese, Onions, B & B Pickles on Buttery Bun \nGiardiniera Mayo  \nRaspberry Ginger Mocktail...',
#     'time_created': '2023-06-19 17:48:04'},
#    {'rating': 4,
#     'text': "Fantastic drinks. Always run into someone fun. \n\nGreat menu. I've to try the sauerkraut and pork meatball appetizer.",
#     'time_created': '2023-04-12 18:46:51'}]},
#  {'name': 'La Tavola',
#   'rating': 4.5,
#   'reviews': [{'rating': 3,
#     'text': "I'm a foodie with an Italian heritage. The homemade pasta was authentic.\nI ordered the pasta with mushrooms and shrimp . The dish was presented dry from all...",
#     'time_created': '2023-08-13 16:46:30'},
#    {'rating': 5,
#     'text': 'Great food great service.  Suggest getting a reservation they are always busy.\n\nThe Italian dishes are all great.',
#     'time_created': '2023-08-01 06:26:29'},
#    {'rating': 3,
#     'text': "La Tavola is a quaint little restaurant in Columbus that is off the beaten path. Upon entrance, we were greeted promptly, and even though we didn't have...",
#     'time_created': '2023-07-21 08:35:54'}]},
#  {'name': 'Cento',
#   'rating': 5.0,
#   'reviews': [{'rating': 5,
#     'text': 'What a night to remember! I highly recommend if you are looking for an upscale Italian restaurant where modern meets traditional, this is the place. My...',
#     'time_created': '2023-09-03 06:55:36'},
#    {'rating': 5,
#     'text': "I've seen this place slowly get built over the last ~1.5 years living in German Village and what a beautiful addition! Stopped in yesterday for dinner on a...",
#     'time_created': '2023-08-28 14:10:36'},
#    {'rating': 5,
#     'text': "What a magical addition to our German village! Food and drinks were great. Pricey but worth it. Pork chop was the table's favorite and can you believe it...",
#     'time_created': '2023-09-02 14:15:49'}]},
#  {'name': "Preston's - A Burger Joint",
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'What a wonderful find!!! We passed this place one day and decided to look it up on Yelp. The reviews encouraged me to give it a try with some family...',
#     'time_created': '2023-08-17 12:22:49'},
#    {'rating': 5,
#     'text': 'Stopped here Saturday afternoon for a casual lunch. The atmosphere was cool and welcoming, very laid back, and very very clean. \nWalking in, the place...',
#     'time_created': '2023-06-04 18:29:34'},
#    {'rating': 5,
#     'text': "Best burger I've had in awhile. Smashed burger goodness! \n\nI've never dined in. Only Door Dash or take out. \n\nI've only ordered a double Mushroom Swiss but...",
#     'time_created': '2023-06-03 17:12:21'}]},
#  {'name': 'Los Agavez Taqueria',
#   'rating': 5.0,
#   'reviews': [{'rating': 5,
#     'text': 'The hype is real. \n\nBirria tacos are on weekends only. As others have said, check the weekend specials on their socials. Birria tacos can be ordered as 3 or...',
#     'time_created': '2023-07-02 08:07:32'},
#    {'rating': 5,
#     'text': "I read on the 614 Now that Yelp rated Los Agavez Taqueria food truck as the 63th out of 100 best taco spots IN THE COUNTRY. That's insanely impressive! I...",
#     'time_created': '2023-05-18 11:48:38'},
#    {'rating': 5,
#     'text': 'best tacos ever\n\nmust stop everything your doing because this taco spot is the spot\n\nyou aint never had a taco like this \n\namazing service i leave with a...',
#     'time_created': '2023-03-10 14:09:28'}]},
#  {'name': "Matt and Tony's Wood Fired Kitchen",
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'Amazing!!!  Everything was perfect from the service to the food simply awesome!!  \n\nAmbiance was also great!',
#     'time_created': '2023-05-19 17:10:04'},
#    {'rating': 5,
#     'text': 'Went on a Friday evening and the restaurant and bar were full.  We were lucky and just had a 2 min wait while a table was reset.\n\nThe building is medium...',
#     'time_created': '2023-03-27 13:16:39'},
#    {'rating': 3,
#     'text': 'We ate here on a Saturday night. We has been moving apartments all weekend, so we were pretty exhausted. We walked in as things were winding down, it was a...',
#     'time_created': '2023-03-23 12:22:51'}]},
#  {'name': 'The Eagle',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'The Eagle in Columbus, Ohio is an absolute gem for anyone craving delicious comfort food with a Southern twist. From the moment you step inside, the rustic...',
#     'time_created': '2023-07-26 09:46:43'},
#    {'rating': 4,
#     'text': 'Went here with a very large group of people to celebrate a big birthday. They have a party room available for up to 18, and it was the perfect private spot....',
#     'time_created': '2023-08-01 19:23:00'},
#    {'rating': 3,
#     'text': 'One of the many restaurant options down in the Short North. This one is known for fried chicken and "southern" fare.\n\nEnvironment is super casual and...',
#     'time_created': '2023-07-07 17:41:24'}]},
#  {'name': 'TownHall',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'Great service and great food! Really enjoyed the extensive draft beer selection and servers were awesome!',
#     'time_created': '2023-08-08 21:12:19'},
#    {'rating': 5,
#     'text': 'Definitely the best bar I have been to in Columbus. We went here while we were in town for the weekend. The bartender was outstanding and the food was...',
#     'time_created': '2023-09-03 06:39:06'},
#    {'rating': 4,
#     'text': 'Local Yelp Elites Brent W. and Samantha K.  recommended that I check out TownHall, a restaurant that serves a health-conscious fare. My family and I sat...',
#     'time_created': '2023-08-06 14:56:35'}]},
#  {'name': 'The Crest',
#   'rating': 3.5,
#   'reviews': [{'rating': 5,
#     'text': 'Fantastic! Neighborhood gem! Everything was great. Best fries in Franklin county. Happy hour was all night long. Cocktails were amazing and generous. Patio...',
#     'time_created': '2023-07-03 19:38:25'},
#    {'rating': 2,
#     'text': 'The Crest serves what I consider to be interesting takes on some midwest standards and some of their drinks. I enjoyed what I ate and drank, and I hope that...',
#     'time_created': '2023-04-24 18:44:44'},
#    {'rating': 4,
#     'text': 'We came for HH and to celebrate a happy event. HH is 4-close on Mondays. Thats crazy!  Nice selections too in the critical food and drink areas. It was...',
#     'time_created': '2022-11-08 19:57:14'}]},
#  {'name': 'Gyropolis',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'Only been open a few short days, but I really enjoyed my meal here and thought it was reasonably priced.  I got the gyro (in the pita not the sandwich)...',
#     'time_created': '2023-08-21 15:37:56'},
#    {'rating': 5,
#     'text': "The food is great, really good gyros and fish and chips. The gyropolis sauce is addicting. The service is immaculate, and super fast as well. Didn't expect...",
#     'time_created': '2023-08-25 15:01:05'},
#    {'rating': 5,
#     'text': 'The owner greeted us and paid attention to details on our order . The falafel was hot and the Greek salad was cold .  The food arrived promptly . The...',
#     'time_created': '2023-08-22 18:26:55'}]},
#  {'name': 'Basi Italia',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': "If you're reading reviews for Basi, you should just go ahead and make a reservation now.\nAs an Italian girl who avoids carbs, a visit to an Italian...",
#     'time_created': '2023-08-07 05:53:12'},
#    {'rating': 5,
#     'text': 'As you already know, we decided to make Summer 2023 the season of patio dining! We continued our weekly visit of patios of Columbus by visiting BASI in the...',
#     'time_created': '2023-07-18 12:18:02'},
#    {'rating': 5,
#     'text': "There's so much to like about Basi. Friendly staff, nice patio and great Italian food. With a party of two, I had the opportunity to try multiple dishes and...",
#     'time_created': '2023-07-07 21:49:57'}]},
#  {'name': "Marcella's",
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'We ate here last Sunday night. It was a really good this time.\n\nThe wine pours are excellent. I got the chicken parm, my wife got fettuccine and meatball....',
#     'time_created': '2023-08-09 05:54:18'},
#    {'rating': 2,
#     'text': 'I wanted to love this spot so badly, and upon arrival I thought we would!\n\nMade reservations and were seated quickly. Got wine to share, ordered calamari....',
#     'time_created': '2023-09-03 09:33:03'},
#    {'rating': 5,
#     'text': 'My friends had some gift cards they wanted to use and we said, "Let\'s go to Marcella\'s!" I have never been before so it was a welcomed treat! This location...',
#     'time_created': '2023-08-08 11:23:29'}]},
#  {'name': 'Bonifacio',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'Went here for restaurant week - delicious food, accommodating of dietary restrictions, nice vibe inside. The wait for food was slightly longer because it...',
#     'time_created': '2023-07-26 17:36:37'},
#    {'rating': 5,
#     'text': "I want to kick myself. I've been hearing about how great this place is, and it's taken me THIS long to try it! (Reminds me of another restaurant--Jiu Thai...",
#     'time_created': '2023-08-18 12:31:14'},
#    {'rating': 5,
#     'text': 'Fantastic little locally owned restaurant. The food is really tasty and a modern, fun take on Filipino food. They have a lunch, dinner, and brunch menu, and...',
#     'time_created': '2023-08-12 16:39:25'}]},
#  {'name': 'Brazilian Grill & Bakery',
#   'rating': 5.0,
#   'reviews': [{'rating': 5,
#     'text': "I'd been here when it was Estilo Brazil, partly because I used to have Brazilian cars (yes, they're a thing.)  I'm not sure if it has changed owners but it...",
#     'time_created': '2023-08-25 10:54:01'},
#    {'rating': 5,
#     'text': 'Have you been to a Brazilian Steakhouse before? If not, get it in your bucket list. There is a few chain Brazilian Steakhouse around Columbus. If you are...',
#     'time_created': '2023-05-22 18:38:45'},
#    {'rating': 5,
#     'text': "Had the pleasure of our first visit just last weekend and couldn't have had a better experience! \n\nThe restaurant inside is clean and really pretty. It is a...",
#     'time_created': '2023-03-20 14:28:33'}]},
#  {'name': 'The Walrus',
#   'rating': 4.0,
#   'reviews': [{'rating': 4,
#     'text': 'Awesome place for a drink and good bar food!\n\nCool place to hang out.\n\nPeople were nice.',
#     'time_created': '2023-05-06 07:12:58'},
#    {'rating': 3,
#     'text': 'Multiple people told me this was a must try place, so I was super excited to go for restaurant week. I tried their $30 deal and ordered the Tavern pretzels,...',
#     'time_created': '2023-07-31 05:34:42'},
#    {'rating': 3,
#     'text': "I came here last Monday and Tuesday and honestly, I'd give it 4 stars, but thought the staff was kinda rude on my second visit. On my first visit, we got...",
#     'time_created': '2023-03-09 12:36:44'}]},
#  {'name': 'Northstar Café',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': "I am obsessed with Northstar's veggie burger! I have never been someone who was super into veggie burgers, but this one is so incredible and has the perfect...",
#     'time_created': '2023-03-21 12:46:42'},
#    {'rating': 2,
#     'text': 'The food is consistent and always good.  However, the prices are out of control.  Customers order at a counter, pour their own pop/water and staff brings...',
#     'time_created': '2023-07-08 03:25:02'},
#    {'rating': 4,
#     'text': 'Stopped in today with my wife after an appointment in Columbus. Very trendy with an interesting business model. My wife ordered the Margherita Pizza while...',
#     'time_created': '2023-07-06 16:07:45'}]},
#  {'name': 'Emmett’s Cafe',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': "Delicious food. \nGreat coffee. \nExcellent service. \nAmazing vibe. \nI 100% recommend Emmett's Cafe!",
#     'time_created': '2023-07-06 14:38:44'},
#    {'rating': 4,
#     'text': "Ben, who manages customer service for Emmett's, reached out to me to apologize and explain the circumstances of that particular day. All things said: I do...",
#     'time_created': '2023-08-15 17:21:08'},
#    {'rating': 4,
#     'text': "This was my second time coming to Emmett's for weekend brunch. The first week, I ordered the avocado toast to go. It was amazing, great flavor, super fresh...",
#     'time_created': '2023-08-15 12:19:08'}]},
#  {'name': 'Service Bar',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'Before the Stevie Nicks and Billy Joel concert, my family and I had an early dinner at Service Bar by Middle West Spirits. We were seated at a U-shaped...',
#     'time_created': '2023-08-06 15:41:20'},
#    {'rating': 4,
#     'text': "I've been searching for restaurants that have squash blossoms on their menu and was glad I finally made it in to Service Bar. The restaurant is connected to...",
#     'time_created': '2023-09-01 05:18:56'},
#    {'rating': 4,
#     'text': "Re-opened earlier this month after a hiatus during COVID featuring a new chef, Chris Connolly. It's an upscale place which you can tell from the interior...",
#     'time_created': '2022-10-29 21:08:46'}]},
#  {'name': 'Ampersand Asian Supper Club',
#   'rating': 4.5,
#   'reviews': [{'rating': 4,
#     'text': 'The service was great and the place looks very nice! We got the lunch special of ramen and a side (fries and miso soup)\n\nBoth the miso soup and the fries...',
#     'time_created': '2023-07-12 15:42:03'},
#    {'rating': 5,
#     'text': '10/10 would recommend you try Ampersand \n\nWe had family in town visiting and reserved the Tatami Room which was a very cool experience. The Tatami Room is a...',
#     'time_created': '2023-06-27 19:47:52'},
#    {'rating': 3,
#     'text': "Gyoza and dipping sauce were great. The crab rangoon were crisp and a little fishy? We're used to sweet crab. \n\nShoyu ramen (confit chicken) has a very...",
#     'time_created': '2023-08-07 08:45:33'}]},
#  {'name': "Jeff Ruby's Steakhouse - Columbus",
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': "Jeff Ruby's Steakhouse checks more boxes than you even know are there to be checked!  The first look is jaw droppingly gorgeous!  From the crystal...",
#     'time_created': '2023-07-08 12:58:18'},
#    {'rating': 2,
#     'text': 'Since I began going to JR last year, it has been a four or 5-star experience in every imaginable way. This is a review of my visit last night for a business...',
#     'time_created': '2023-08-17 05:41:19'},
#    {'rating': 4,
#     'text': 'First time visiting Jeff Rubys, walking in you are just blown away by the ambiance and decor. It feels so luxurious immediately. We had a reservation and...',
#     'time_created': '2023-06-11 09:50:07'}]},
#  {'name': 'Kyushu Ramen Bar',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'Wife and I came in on a Friday at 5:00. The place was completely empty but slowly filled up in the next 30 minutes. The place was clean and had a small town...',
#     'time_created': '2023-04-10 08:04:12'},
#    {'rating': 1,
#     'text': 'Blech.\n\nGot the Tonkatsu with Pork Chashu. The broth was pretty good actually. The noodles were a bit underdone but passable. The pork was absolutely...',
#     'time_created': '2023-02-23 17:17:32'},
#    {'rating': 3,
#     'text': "Great service! Nice ambiance,  very cozy and cool decor. The fried chicken app was good. It had a flavor that really stood out that my fiance and I couldn't...",
#     'time_created': '2023-08-01 17:47:53'}]},
#  {'name': 'Skillet',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'Skillet was an amazing experience 10/10 recommend. The food is phenomenal, perfectly seasoned and cooked to perfection. Service is amazing, everyone is so...',
#     'time_created': '2023-08-06 12:22:55'},
#    {'rating': 5,
#     'text': 'Excellent food and value!\n\nThere are a lot of great choices on the menu, and everything we had was absolutely delicious. The Huevos Rancheros, the French...',
#     'time_created': '2023-03-30 23:09:47'},
#    {'rating': 2,
#     'text': 'Skillet has been on our list of brunch places to try for quite some time. We finally gave it a go, and had heard that there is usually a wait because the...',
#     'time_created': '2023-08-06 11:43:27'}]},
#  {'name': "Scotty's Cafe",
#   'rating': 5.0,
#   'reviews': [{'rating': 5,
#     'text': "We stopped by Scotty's Cafe for breakfast and found a true gem! We were greeted by Gina, Scotty's wife. It felt like she was a long-lost friend. Every...",
#     'time_created': '2023-08-04 16:26:59'},
#    {'rating': 5,
#     'text': "Took a group of 9 for lunch today. Ages ranged from ten to 84. Everyone had a great meal and the service was probably the best I've experienced in some...",
#     'time_created': '2023-08-07 14:44:53'},
#    {'rating': 5,
#     'text': "This was our first visit to Scotty's Cafe. We loved everything about this family owned business. The food was delicious, (we all had breakfast.) We met the...",
#     'time_created': '2023-07-22 06:04:04'}]},
#  {'name': 'Forno Kitchen + Bar',
#   'rating': 4.0,
#   'reviews': [{'rating': 4,
#     'text': 'Food was great one of the best burgers I ever had, had the spiked strawberries they were delicious!!',
#     'time_created': '2023-07-20 21:06:58'},
#    {'rating': 5,
#     'text': "One of my favorite places in Columbus for brunch. Forno's biscuits and gravy, paired with a mimosa, is a breakfast success story. \n\nInside is comfortable,...",
#     'time_created': '2023-05-10 09:58:52'},
#    {'rating': 4,
#     'text': 'Service- 5/5 the server was very friendly and even helped us move from our table initially because there was a group of people who were being too loud next...',
#     'time_created': '2023-09-02 14:16:20'}]},
#  {'name': 'Pierogi Mountain',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'My husband and I were visiting Columbus for a conference. Ordered delivery here for lunch and so glad we did. Everything we ate was so delicious and full of...',
#     'time_created': '2023-08-01 11:29:09'},
#    {'rating': 5,
#     'text': "We were looking for someplace just a little bit less conventional for our first dinner during our stay in Columbus, and boy did this place satisfy that! I'm...",
#     'time_created': '2023-04-17 07:46:48'},
#    {'rating': 4,
#     'text': 'Pierogies are a luxurious comfort food from my youth. My parents worked hard, but we were not elaborate eaters, and our meals were often wonderfully...',
#     'time_created': '2023-08-29 17:11:52'}]},
#  {'name': 'Koso',
#   'rating': 5.0,
#   'reviews': [{'rating': 5,
#     'text': 'They are located within the East Market. The staffs are super nice. They have a limited table top seating at their stand. But there are plenty of seating...',
#     'time_created': '2022-12-20 18:22:50'},
#    {'rating': 5,
#     'text': "Tiny, and I had to walk all the way around the market to find them.  Look for the sign and a few stools, beside Winston's I think.\n\nSmall menu, and I wanted...",
#     'time_created': '2022-12-06 15:13:27'},
#    {'rating': 4,
#     'text': 'This is such a fun and casual spot to grab food. This is my first time at the East Market and trying out Koso. I loved the kimbap and their kimchi...',
#     'time_created': '2022-12-22 12:40:53'}]},
#  {'name': "Wolf's Ridge Brewing",
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'Excellent food.  Great ambiance and flow.  Service was great for more than 15 people.  Everyone had a great and pleasant evening.  Will come back.',
#     'time_created': '2023-07-19 16:58:56'},
#    {'rating': 5,
#     'text': 'Came here for brunch for the first time! Service was prompt and I really liked the ambiance of the dining area. \n\nThe food was amazing. Portion sizes were...',
#     'time_created': '2023-05-04 06:44:36'},
#    {'rating': 3,
#     'text': "Since my first review, I've been to Wolf's Ridge 4 or 5 times.  The food is always top-notch, the beer is always very good, and the people are always great....",
#     'time_created': '2023-06-28 09:42:41'}]},
#  {'name': 'The 1126 Restaurant',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': "I'm updating my review. The sushi rolls here are fantastic -- artistic and delicious. We ordered several rolls (galaxy roll, blue crab roll, dynamite\nRoll,...",
#     'time_created': '2023-03-19 15:58:31'},
#    {'rating': 3,
#     'text': "Visited 1126 with some friends this week.\nService was prompt and friendly. It's a cute little spot in the SN and was busy even for a Wednesday. \n\nI had the...",
#     'time_created': '2023-08-31 16:52:22'},
#    {'rating': 4,
#     'text': 'Located in the Short North off of High street this sushi place used to be packed and hard to get a reservation.  Its a little easier to get a table now but...',
#     'time_created': '2023-08-24 20:36:19'}]},
#  {'name': 'Speck Italian Eatery',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'Hands down absolutely one of my favorite restaurants in Columbus, and definitely my favorite Italian restaurant. The Fungi mushroom pasta was super creamy...',
#     'time_created': '2023-09-02 10:57:37'},
#    {'rating': 5,
#     'text': "It's been a hot minute since I've done a Yelp review, but Speck is worth logging in for. My girlfriend and I came here to celebrate our birthdays (last...",
#     'time_created': '2023-09-01 04:04:49'},
#    {'rating': 4,
#     'text': 'Great spot and loved the vibes here. Staff was very friendly, food was delicious, and both food & wine were adequately priced. Our server was super...',
#     'time_created': '2023-08-26 08:23:54'}]},
#  {'name': 'The Guild House',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'Awesome atmosphere and service.\n\nI came here for brunch on a Saturday morning. Service was great, quick and super friendly. I ordered a Bloody Mary and the...',
#     'time_created': '2023-05-30 20:01:12'},
#    {'rating': 4,
#     'text': "I'd give this 3.5 stars if that was an option...\n\nWe started with the burrata and avocado which was very tasty but meager in size. I got the gnocchi which...",
#     'time_created': '2023-05-25 18:31:30'},
#    {'rating': 5,
#     'text': "Had such an amazing dinner at The Guild House for my husband's birthday. \n\nTo drink:\n〰 Cocktail for two: Served in a glass porthole and changes seasonally....",
#     'time_created': '2023-03-30 17:36:53'}]},
#  {'name': 'Myungrang Hot Dog',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': "If you're ever in the mood for fair style cheese on a stick or corn dogs, I highly recommend this place. Not only will you satisfy your cravings, but this...",
#     'time_created': '2023-07-18 04:36:09'},
#    {'rating': 2,
#     'text': 'I was craving some Korean dogs and I must say the experience was a 1/10 as you can see the area was kind of bland. They were playing some cool kpop which I...',
#     'time_created': '2023-07-28 16:27:26'},
#    {'rating': 4,
#     'text': 'This was a fun place to try. We had a cheddar cheese dog rolled in sugar, and a mozzarella and potato. Rolling a cheesy hotdog in sugar is weird, but it...',
#     'time_created': '2023-07-23 06:59:42'}]},
#  {'name': 'Lan Zhou Noodles',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': "First off, let me just say this is the best Chinese food I've ever had in my life. The flavors are phenomenal. \n\nThe people that operate this establishment...",
#     'time_created': '2023-03-30 16:06:09'},
#    {'rating': 5,
#     'text': 'Lan Zhou is my secret hole-in-the-wall gem! Easy to miss just by the OSU Union, this tasty and authentic restaurant offers just the perfect hot noodle soups...',
#     'time_created': '2023-03-01 11:16:59'},
#    {'rating': 4,
#     'text': 'A tiny shop right on south campus that is a popular spot for quick chinese food. I was excited to see 榨 菜肉丝 面 (Mustard & Shredded Pork Noodle Soup) on the...',
#     'time_created': '2022-12-12 11:29:48'}]},
#  {'name': 'FYR Short North',
#   'rating': 4.0,
#   'reviews': [{'rating': 3,
#     'text': 'The ambience is very nice as was the service! Ryan was great. The appetizers were mostly good- empanadas, the tomato and the lobster were great. The...',
#     'time_created': '2023-07-18 18:50:16'},
#    {'rating': 5,
#     'text': 'Food is always delicious here! Not a single dish I have tried has been less than excellent! My sister is a vegetarian and she even said her meal was...',
#     'time_created': '2023-07-18 18:22:04'},
#    {'rating': 5,
#     'text': 'CJ and his team may do hotel dining best. I arrived with a small party of coworkers that continued to grow throughout the night. And we were provided new...',
#     'time_created': '2023-07-02 08:57:48'}]},
#  {'name': 'SŌW Plated',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'Finally, a local place that hits all the marks: Lovely ambiance, attentive service and fresh, healthy, tasty food with great portions.\n\nStarted with the...',
#     'time_created': '2023-08-12 18:43:28'},
#    {'rating': 5,
#     'text': 'Back again, 1 weeks later!!\nMac and Cheeze the Pad Thai, the Blistered Shisisto \nOMG\nWonderful atmosphere and super service \n\nVegan heaven on Lane Ave',
#     'time_created': '2023-07-29 15:17:39'},
#    {'rating': 4,
#     'text': 'The layout of the restaurant gives you a sense of openness.  There are flowers, which are simple, but they are adding the simple, yet sophisticated and...',
#     'time_created': '2023-06-20 22:33:45'}]},
#  {'name': 'Watershed Kitchen & Bar',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'Wow!!! This place is a must! Exceptional service food and atmosphere. Each part of the building is a whole new vibe. They have a 3 course meal for...',
#     'time_created': '2023-08-12 13:36:33'},
#    {'rating': 2,
#     'text': "Restaurant reeked of rubbing alcohol smell that was very noticeable... it was bad. I understand it's a distillery, but other distilleries don't smell so...",
#     'time_created': '2023-07-24 18:18:50'},
#    {'rating': 3,
#     'text': "I gotta say that I'm super disappointed to only give this place 3 stars as I have always enjoyed my experiences coming to the bottle shop. However, this was...",
#     'time_created': '2023-06-03 09:24:20'}]},
#  {'name': 'Fireproof Restaurant',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': "Excellent service and food. Love the tapa because you can try so many things all of which we really thought were excellent!  Our server was Devon. Can't...",
#     'time_created': '2023-08-11 16:21:31'},
#    {'rating': 5,
#     'text': 'Great meal at Fireproof in the Short Nortb. Lots of vegetarian options!\nDelicious food, great cocktail menu, high prices so be prepared for an expensive...',
#     'time_created': '2023-08-27 06:44:17'},
#    {'rating': 5,
#     'text': 'The NEW MENU AT @fireproofcolumbus IS FIRE!! \n- WHIPPED LABNEH \n- PATATAS BRAVAS \n- CAESAR SALAD \n- GRILLED SHRIMP \n- LAMB MEATBALLS \n- CHICKEN MILANESA \n*...',
#     'time_created': '2023-08-15 04:58:21'}]},
#  {'name': 'Lavash Cafe',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': "One warning, the portions are huge! My family is vegan and everything we had -- mujadra, falafel, hummus, grape leaves, and more -- was so so delicious. I'm...",
#     'time_created': '2023-06-09 16:26:00'},
#    {'rating': 5,
#     'text': "I kept hearing great things about this place and they were right! \n\nMy husband even said it was the best Mediterranean food he's ever had! The lamb was...",
#     'time_created': '2023-02-16 14:20:15'},
#    {'rating': 5,
#     'text': "Not sure why I waited so long to come here. I've been hearing about it for years, rave reviews. It's a little out of my way, but I could've made a better...",
#     'time_created': '2022-11-15 10:20:05'}]},
#  {'name': "Hank's Texas BBQ",
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'Wow, what an amazingly yummy place to visit. My husband got the Birria tacos, from a Hispanic point of view, "it taste AMAZING!" Lol\nI for the pulled pork,...',
#     'time_created': '2023-08-01 13:23:20'},
#    {'rating': 4,
#     'text': 'Came with a group of 8 for a birthday on a Wednesday. We were quickly sat, no issues with waiting. Food came out very quickly as well. We started with the...',
#     'time_created': '2023-08-23 09:13:56'},
#    {'rating': 2,
#     'text': "BBQ spot in the old Old Skool location in south Clintonville. \n\nI've been curious and tried this recently for lunch. The food was mediocre at best--servings...",
#     'time_created': '2023-05-31 07:02:20'}]},
#  {'name': 'Rossi Bar And Kitchen',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'Thank you Shiloh! So informative friendly and welcoming. Sat at the bar and everything coming out of the kitchen looks fresh and amazing. Found a bar seat...',
#     'time_created': '2023-06-09 16:09:37'},
#    {'rating': 4,
#     'text': 'This place has been around forever but through multiple reopenings which changes the consistency and quality immensely. We came in tonight to try the new...',
#     'time_created': '2023-02-20 17:38:47'},
#    {'rating': 3,
#     'text': 'I had to check this place out during restaurant week. Upon entering, you are greeted by ambulance with multiple gorgeous light fixtures. The waiters are...',
#     'time_created': '2022-07-29 08:19:12'}]},
#  {'name': "Schmidt's Sausage Haus",
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'My wife and I are from Cleveland and make a trip one or two times a year. Good service and good food. We enjoy the old school decor. Only down side is how...',
#     'time_created': '2023-08-12 13:25:23'},
#    {'rating': 5,
#     'text': 'Was here a few months ago with a friend and decided I needed to come back because it was just so good. I highly recommend the pretzel bites with beer cheese!',
#     'time_created': '2023-08-13 06:29:08'},
#    {'rating': 5,
#     'text': "Schmidt's is a Columbus icon and in my opinion somewhere every native or tourist alike should visit at least once. The interior isn't quite as big as other...",
#     'time_created': '2023-08-07 15:43:16'}]},
#  {'name': 'Koshi - Korean food and sushi',
#   'rating': 5.0,
#   'reviews': [{'rating': 5,
#     'text': 'A must visit after or before your grocery shopping. Located inside saraga market, it is convenient and offers seating area for dining in. \n\nDak gangjeong-...',
#     'time_created': '2023-07-04 08:10:39'},
#    {'rating': 4,
#     'text': 'Got food for to go and it was pretty good.\n\nI ordered spicy pork and Korean Fried Chicken. Both dishes were different from what I used to have.\nSpicy pork...',
#     'time_created': '2023-04-27 14:04:50'},
#    {'rating': 4,
#     'text': 'Salmon roll was great, fast service! Little on the pricier side but that typically comes with a good hall.',
#     'time_created': '2023-09-03 21:44:38'}]},
#  {'name': 'Yats Grandview',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': "Pretty decent Yats. Food was on par for the place\n\nTheir hot sauce wall wasn't as big as the old Valparaiso one (RIP) but they had some goof options",
#     'time_created': '2023-07-04 09:48:52'},
#    {'rating': 5,
#     'text': "Cajun food in the midwest that's actually good for a change.\n\nCheap etoufees and gumbos, served up quickly at reasonable prices. Order at the counter. No...",
#     'time_created': '2023-06-26 20:20:11'},
#    {'rating': 5,
#     'text': 'This is one of my favorite spots in Columbus.  Service is good.  No waiters or anything, just one at the register one in the back usually.  Order your food...',
#     'time_created': '2023-03-06 15:50:37'}]},
#  {'name': 'The Woodbury',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'Great happy hour! And the drinks are wonderful. Highly recommend the nachos. We sat at the bar where we could easily watch the TVs for our sports game that...',
#     'time_created': '2023-07-12 05:10:13'},
#    {'rating': 5,
#     'text': 'The ambiance, the hosts, patrons and my waitress were all wonderful. I went on Sunday and it was booked and busy. I ordered the breakfast burger and it was...',
#     'time_created': '2023-07-18 14:33:00'},
#    {'rating': 2,
#     'text': 'Look at the photos and menu before you take the time to come out here. If you are interested in what you see, then come.\n\nI did not happen to be interested...',
#     'time_created': '2023-08-19 09:39:02'}]},
#  {'name': 'Bistrolino',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': "the restaurant was completely packed. It's a rare gem in German village. We were seated in the bar lounge was had an amazing ambiance and aesthetic. Highly...",
#     'time_created': '2023-08-16 07:18:45'},
#    {'rating': 5,
#     'text': 'We just got back from having dinner at Bistrolino.  Wow!  This place is full of character with two entirely different vibes going on here.  The restaurant...',
#     'time_created': '2023-06-22 16:07:19'},
#    {'rating': 4,
#     'text': "Grading on a curve. It's not best-in-class Italian, but it's a perfectly enjoyable meal. We sat outside, which was lovely on a summer night. For two of us,...",
#     'time_created': '2023-07-14 15:29:54'}]},
#  {'name': 'Nada',
#   'rating': 4.0,
#   'reviews': [{'rating': 4,
#     'text': "Love this restaurant but continue to be disappointed with unnecessary menu changes.  I'm all for evolution yet question why fan favorites are taken off the...",
#     'time_created': '2023-08-12 11:42:18'},
#    {'rating': 5,
#     'text': 'Nada is one of my favorite restaurants. The food is always on point and I have tried many dishes/sides. The enchiladas, the caramelized cauliflower tacos...',
#     'time_created': '2023-08-08 16:44:15'},
#    {'rating': 4,
# ...
#     'time_created': '2023-04-30 13:46:46'},
#    {'rating': 5,
#     'text': "Perfect afternoon stop. Food, drinks and service all top notch!  Great vibe!  I'll be back!  Thanks Maggie.",
#     'time_created': '2023-08-27 15:12:33'},
#    {'rating': 5,
#     'text': 'Ever since "Covid", service and food has really gone down hill (in my opinion and experience) BUT this place has been phenomenal during both of our visits....',
#     'time_created': '2023-08-18 11:46:57'}]},
#  {'name': 'Santos614',
#   'rating': 4.0,
#   'reviews': [{'rating': 4,
#     'text': 'Came to visit our daughter at Ohio State and she was craving something fancy and this place definitely fits the bill.\n\nRestaurant is stunning, very...',
#     'time_created': '2023-04-03 16:13:59'},
#    {'rating': 3,
#     'text': "The chophouse 614 is now Santos. They've kept certain parts of the chophouse menu but it is quite different now. \n\nThe service was very good. The ambience...",
#     'time_created': '2023-05-13 19:36:37'},
#    {'rating': 2,
#     'text': 'Had dinner on a Saturday evening to celebrate the engagement of my brother in law. The lobby was full of people so it seemed like a bustling  place. The...',
#     'time_created': '2023-03-13 11:46:41'}]},
#  {'name': 'Khaja Ghar Restaurant & Bar',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': "What an amazing flavor and taste that reminds the himalayas. The two dishes listed are outstanding and can't mention much.\nPork Sekuwa, Noodle Soup and...",
#     'time_created': '2023-03-08 08:10:21'},
#    {'rating': 5,
#     'text': "My wife and I visited a few weeks ago. Had momos, vegetable pakoras, and pork sekuwa. By far the best Nepali food I've ever had! Very clean on the inside...",
#     'time_created': '2023-09-02 08:22:30'},
#    {'rating': 4,
#     'text': 'Khaja Ghar has been open for a month and a half, and according to the owner has had a rough time getting the unit up to speed. When I came in for lunch...',
#     'time_created': '2023-02-26 18:06:57'}]},
#  {'name': 'Arepazo Tapas Bar Grille',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'We love Arepazo. Flavorful food...cilantro sauce is absolutely wonderful--spicy and mild are both offered..spicy, please!!\nPotatoes with cilantro...',
#     'time_created': '2023-07-08 19:24:15'},
#    {'rating': 5,
#     'text': 'Latin America eatery close to home. This place is authentic and all the food tastes fresh. Portions were of decent size and left you feeling satisfied. The...',
#     'time_created': '2023-03-27 08:55:34'},
#    {'rating': 4,
#     'text': "I always enjoy the food at this restaurant, which is why I'm so bummed that the other locations closed! I hope this one stays strong because the food is...",
#     'time_created': '2023-03-14 17:00:17'}]},
#  {'name': 'The Thurman Cafe',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'After trying to come to this place several times, but not being willing to wait an hour and a half to be sat, I am so happy I got to experience the famous...',
#     'time_created': '2023-09-03 13:50:57'},
#    {'rating': 4,
#     'text': 'There was a 25-30 minute wait for lunchtime and they do not take reservations, but there were benches inside and outside to wait on. \n\nIt has more of a...',
#     'time_created': '2023-08-19 12:53:56'},
#    {'rating': 5,
#     'text': "Easy to find but I can imagine on a busy night finding a parking spot could be difficult. It's a small lil place but with a big burger to offer! \n\nThe...",
#     'time_created': '2023-08-10 03:27:14'}]},
#  {'name': 'The Mercury Diner',
#   'rating': 4.0,
#   'reviews': [{'rating': 4,
#     'text': 'I like the diner.  Good ambience and food was solid.  Our server was well versed in the menu and was helpful.   I enjoyed my patty melt.  The fries were the...',
#     'time_created': '2023-07-17 17:56:24'},
#    {'rating': 4,
#     'text': 'I liked the design and decor of this place. My menu (which I think doubles as a placemat) had food on it from a previous meal (see photo). \n\nThe food (I had...',
#     'time_created': '2023-04-30 10:17:17'},
#    {'rating': 5,
#     'text': "Excellent food. Awesome vibes. Great server. They don't have a kids menu but older kids can definitely get away with splitting some things on the menu....",
#     'time_created': '2023-04-15 07:08:13'}]},
#  {'name': 'Roosters',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': "Casual with decent food. I like the tater tots! When it's not busy, the service is great. It's a popular weekend place!",
#     'time_created': '2023-07-18 19:26:25'},
#    {'rating': 3,
#     'text': "Came here for a lunch with colleagues. The Carolina gold boneless wings were good but varied a lot in size. Makes you feel like you're getting ripped off....",
#     'time_created': '2023-08-06 22:49:31'},
#    {'rating': 5,
#     'text': 'By far the best place for chicken, fried pickles, and all things in between. Roosters was one of the first restaurants that I went to when I moved to...',
#     'time_created': '2022-10-30 18:32:10'}]},
#  {'name': 'Barrio',
#   'rating': 3.5,
#   'reviews': [{'rating': 5,
#     'text': 'Literally my favorite restaurant on campus, I visit at least once a week, often twice. The margs and chips alone are worth the trip but the food has never...',
#     'time_created': '2023-05-31 07:57:37'},
#    {'rating': 3,
#     'text': "The first time I came here a few months ago, I was not impressed at all. I gave Barrio a 2nd chance and can definitely see improvement, but I still don't...",
#     'time_created': '2023-04-19 06:00:32'},
#    {'rating': 3,
#     'text': 'I stopped by on a Friday Night at their OSU location and it is fairly busy. The place is quite big and filled with colorful pendant light fixture. I also...',
#     'time_created': '2022-12-03 09:16:51'}]},
#  {'name': 'Goodwood Brewing',
#   'rating': 3.5,
#   'reviews': [{'rating': 4,
#     'text': "I have reviewed Goodwood once before for a Yelp event but I've since been back twice so wanted to leave a formal review for the restaurant as a whole. All 3...",
#     'time_created': '2023-04-15 10:36:08'},
#    {'rating': 1,
#     'text': 'Terrible experience from start to finish. \n\nServer looked homeless and smelled like straight B.O.\n\nOrdered a lager out of a can and it was served at room...',
#     'time_created': '2023-04-02 07:06:11'},
#    {'rating': 3,
#     'text': "As a venue in the arena district it's alittle disorganized. I don't know if they can handle concert crowds.  We've been to Goodwood Indy (during the Indy...",
#     'time_created': '2023-07-01 04:59:43'}]},
#  {'name': 'Ash & Em',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'The OG burger was great!! The bun was soft and the sauce was delicious!! Great burger!!!',
#     'time_created': '2023-08-24 14:52:51'},
#    {'rating': 1,
#     'text': "The food was made wrong and was garbage. The owners should not be in business. I find it unbelievable that their rating is so high. I'm guessing alot of...",
#     'time_created': '2023-08-18 15:14:40'},
#    {'rating': 1,
#     'text': 'Last time I came here I ordered well done wings. Fail. They were rubbery and clearly not cooked. Today I came for my friends 21st for shots and pizza....',
#     'time_created': '2023-03-31 15:29:15'}]},
#  {'name': 'Satori Ramen Bar',
#   'rating': 4.0,
#   'reviews': [{'rating': 4,
#     'text': 'This was our first time trying Satori Ramen. We ordered take out/ delivery. That was spectacular, as the food was delivered hot and it was packaged well....',
#     'time_created': '2021-10-17 11:29:54'},
#    {'rating': 3,
#     'text': "I want to love this stall. It's super authentic looking, it really gets the fast casual vibe of this dish but...I found it rather lacking.\n\nThe chashu just...",
#     'time_created': '2023-04-24 13:43:49'},
#    {'rating': 1,
#     'text': "Ramen was meh at best. \n\nThe real reason I'm giving it a 1 star is I've been puking all day with food poisoning since eating there. \n\nIt's overpriced for...",
#     'time_created': '2023-03-04 19:16:33'}]},
#  {'name': 'Oshio Station',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'This little "takeout" restaurant is awesome. Nice presentation and variety of flavors for the bento box, and the portions are large!! The tonkatsu and...',
#     'time_created': '2023-01-25 20:08:33'},
#    {'rating': 4,
#     'text': 'Stopped here for a quick lunch. Space is nice and clean. A few high tops inside and few tables outside to eat. They have some premade sushi rolls to grab or...',
#     'time_created': '2023-08-15 12:10:24'},
#    {'rating': 3,
#     'text': "Nice to have a sushi option downtown! This location is on high street, with the commons on the other side. There are a few tables outside if that's your...",
#     'time_created': '2022-08-15 09:36:14'}]},
#  {'name': 'Slurping Turtle',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'food excellent\nservice excellent - Crystal \nambiance - music a little loud at times',
#     'time_created': '2023-08-13 19:49:50'},
#    {'rating': 5,
#     'text': "I came here for a girls night and we loved it. Don't listen to bad reviews. Food was great. Server was nice. Drinks were good! I'd come back for sure.",
#     'time_created': '2023-07-28 16:30:44'},
#    {'rating': 5,
#     'text': 'Omg! Yessss...... \nNever had this style of food before so I was a little bit leery. However, I ordered the Red curry with a side of duck fat chicken wings....',
#     'time_created': '2023-08-04 15:44:58'}]},
#  {'name': 'Bakersfield',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': 'I will never forget when I was living in Cincinnati and Bakersfield opened one street over from me. I was there at LEAST once a week for the incredible...',
#     'time_created': '2023-05-19 16:24:23'},
#    {'rating': 3,
#     'text': "First time dining here. I've passed by this place a million times but never made it past the door. I decided to grab brunch. \n\nThe restaurant has a nice...",
#     'time_created': '2023-03-15 16:08:02'},
#    {'rating': 4,
#     'text': 'BAKERSFIELD - short north \n\nTaco place called Bakersfield? Interesting. THIS is the place to go to try creative tacos and enjoy an assortment of color on...',
#     'time_created': '2023-03-07 19:40:36'}]},
#  {'name': 'Olive & Lime Cafe',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'The service was top-notch, and the food was very fresh & tasty (especially the Pita Bread & hummus)! Olive & Lime has seating for  big families, or you can...',
#     'time_created': '2023-07-21 04:15:01'},
#    {'rating': 5,
#     'text': "One of my favorite places in Columbus! The food is incredible and affordable with many amazing options that never disappoint, and it's a very casual and...",
#     'time_created': '2023-08-27 09:49:45'},
#    {'rating': 5,
#     'text': 'I cannot say enough amazing things about \nOlive & Lime Cafe! \nThe meal is always on point!\nOur server Anna Lee is amazing!\nShe suggested the charbroiled...',
#     'time_created': '2023-07-31 14:05:30'}]},
#  {'name': 'Valters at the Maennerchor',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'Best German food in Columbus by far.\nHangover is best breakfast!\nOwner and staff are amazing!',
#     'time_created': '2023-07-30 14:36:57'},
#    {'rating': 5,
#     'text': "First time in to the Maennerchor...\n\nI don't know why we have not been in here before now because we have been to most the other German restaurants.  This...",
#     'time_created': '2023-07-29 19:55:29'},
#    {'rating': 5,
#     'text': 'Valters is one of my favorite places in Columbus. I love their skillets, Pork Shank, Beer, and everything I have had on the menu.\n\nI recently went with my...',
#     'time_created': '2023-07-26 09:07:06'}]},
#  {'name': 'Goood Friends',
#   'rating': 5.0,
#   'reviews': [{'rating': 5,
#     'text': "From the guys at Wario's, you have to know this place is going to be delicious!\n\nYou can't go wrong with anything you ordered but I loved the Juicy Jackie...",
#     'time_created': '2023-08-28 09:22:10'},
#    {'rating': 5,
#     'text': "I had the opportunity to visit goood Friends for their grand opening this evening at Jackie O's. It's a cloud kitchen inside Jackie Os that serve some...",
#     'time_created': '2023-08-25 21:40:37'}]},
#  {'name': 'Bendi Wok N Bar',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': "I've been here a few times and really like it! The décor is fun and inviting! The food is pricey, but delicious. Expect to spend some money here. \n\nCustomer...",
#     'time_created': '2023-08-07 12:15:58'},
#    {'rating': 5,
#     'text': 'Bendi gets it right on several levels. The vibe of this place is amazing. The decor perfectly fits the diverse pan-Asian cuisine and enhances the...',
#     'time_created': '2023-07-22 13:42:07'},
#    {'rating': 1,
#     'text': 'Tried Bendi today for the first time. Will not try again. Service was beyond poor and most of the food ordered was not edible. When we arrived server told...',
#     'time_created': '2023-06-30 14:37:06'}]},
#  {'name': "Hoyo's Kitchen",
#   'rating': 5.0,
#   'reviews': [{'rating': 5,
#     'text': "Cannot stress enough how AMAZING Hoyo's is!! \nFirstly, I had enough food for 3 meals. That's impressive considering I kept eating until I was stuffed...",
#     'time_created': '2023-08-14 10:26:05'},
#    {'rating': 4,
#     'text': "Excellent food, generous portions, and reasonably priced. This is the first time I've ever had Somalian food and it won't be the last.   Nice seasonings on...",
#     'time_created': '2023-07-26 16:51:38'},
#    {'rating': 5,
#     'text': "If you have never been to Hoyo's Kitchen in the North Market... RUN don't walk there!!!! After just one visit, this place has become top 10 places to eat in...",
#     'time_created': '2023-03-09 07:33:05'}]},
#  {'name': 'Joya’s',
#   'rating': 4.5,
#   'reviews': [{'rating': 5,
#     'text': 'We came here after visiting Agni and it was absolutely amazing!! We got two things to split (all vegetarian):\nBreakfast Sandwich (5/5): all the flavors of...',
#     'time_created': '2023-07-25 13:07:05'},
#    {'rating': 4,
#     'text': 'Amazing food and ambiance! Even though this cute, inspired spot is small, if you get lucky, you can snag the window seat, littered with trinkets and...',
#     'time_created': '2023-08-21 13:50:19'},
#    {'rating': 5,
#     'text': "So glad we finally got a chance to try this place. I think the one complaint I might have is that the hours are pretty limited and they don't take phone...",
#     'time_created': '2023-06-28 14:55:28'}]},
#  {'name': 'Hubbard Grille',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': "Not sure if this is Elite-exclusive, but if you check in here on Yelp, you'll receive a $10 off $40 coupon!\n\nThis time, I ordered the pasta rosa again, and...",
#     'time_created': '2023-08-28 14:39:13'},
#    {'rating': 4,
#     'text': "I came in a group of 13-15 people, but I'll be speaking towards my own food and general observations for this review. In a general summary, the food here is...",
#     'time_created': '2023-03-11 13:00:14'},
#    {'rating': 4,
#     'text': "It has been years since I've been to the Hubbard Grille. My friends and I were in the Short North on Friday evening late and we were happy to get a seat...",
#     'time_created': '2023-07-20 14:38:57'}]},
#  {'name': 'Coco Hot Pot',
#   'rating': 4.0,
#   'reviews': [{'rating': 5,
#     'text': "This place has got to be the best hot pot spot I've tried and this includes Chinatown in Chicago.\n\nThe waitstaff are attentive and helpful in explaining the...",
#     'time_created': '2023-05-31 13:29:44'},
#    {'rating': 4,
#     'text': 'Several people went out to eat and most were happy with their food and service.  I ordered the Kung Pao Tofu and expected it to be hot and spicy.  It was...',
#     'time_created': '2023-08-28 12:11:14'},
#    {'rating': 5,
#     'text': 'Great spot for family (friend) dining. The servings are large and great to share. Tons of hot pot choices, from order sets to a la carte. Variety of soup...',
#     'time_created': '2023-07-01 07:32:37'}]},
#  {'name': "Ena's Caribbean Kitchen", 'rating': 4.0, 'reviews': []}]
